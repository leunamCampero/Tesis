# %%
from representations import *

# %%
s = YoungTableaux([2,2,1,1,1],[3,2,2])

# %%
s.MNR()
# Out:
# [[[1, 2], [1, 2], [1], [3], [3]], [[1, 3], [1, 3], [1], [2], [2]]]

# %% [markdown]
# ![img](./obipy-resources/UXwWf0.png)

# %%
s.CMNR()

# %% [markdown]
# ![img](./obipy-resources/G2XTVl.png)

# %%
c1 = Group_p_chains([(1,2,3)],[-3])
c2 = Group_p_chains([(1,2,3)],[-5])
c3 = Group_p_chains([(2,3,1)],[7])
c4 = Group_p_chains([(2,3,4)],[-2])

# %%
c=c1+c2
c.dic

# %% [markdown]
# ![img](./obipy-resources/Xr8ds2.png)

# %%
g=nx.complete_graph(5)
g5 = grafica_de_emparejamiento(g)
nx.draw(g5, with_labels='True')

# %%
m5 = SimplicialComplex(g5)
m5.n_faces(1)
# Out:
# [((0, 1), (2, 3)), ((0, 1), (2, 4)), ((0, 1), (3, 4)), ((0, 2), (1, 3)), ((0,
# 2), (1, 4)), ((0, 2), (3, 4)), ((0, 3), (1, 2)), ((0, 3), (1, 4)), ((0, 3), (2
# , 4)), ((0, 4), (1, 2)), ((0, 4), (1, 3)), ((0, 4), (2, 3)), ((1, 2), (3, 4)),
#  ((1, 3), (2, 4)), ((1, 4), (2, 3))]

# %%
m5.elementary_chain(((0,1),(2,3))).dic
# Out:
# {((0, 1), (2, 3)): 1, ((2, 3), (0, 1)): -1}

# %%
v=m5.group_of_oriented_p_chains(1)
v.dic
# Out:
# {((0, 1), (2, 3)): 1, ((0, 1), (2, 4)): 1, ((0, 1), (3, 4)): 1, ((0, 2), (1, 3
# )): 1, ((0, 2), (1, 4)): 1, ((0, 2), (3, 4)): 1, ((0, 3), (1, 2)): 1, ((0, 3),
#  (1, 4)): 1, ((0, 3), (2, 4)): 1, ((0, 4), (1, 2)): 1, ((0, 4), (1, 3)): 1, ((
# 0, 4), (2, 3)): 1, ((1, 2), (0, 3)): -1, ((1, 2), (0, 4)): -1, ((1, 2), (3, 4)
# ): 1, ((1, 3), (0, 2)): -1, ((1, 3), (0, 4)): -1, ((1, 3), (2, 4)): 1, ((1, 4)
# , (0, 2)): -1, ((1, 4), (0, 3)): -1, ((1, 4), (2, 3)): 1, ((2, 3), (0, 1)): -1
# , ((2, 3), (0, 4)): -1, ((2, 3), (1, 4)): -1, ((2, 4), (0, 1)): -1, ((2, 4), (
# 0, 3)): -1, ((2, 4), (1, 3)): -1, ((3, 4), (0, 1)): -1, ((3, 4), (0, 2)): -1,
# ((3, 4), (1, 2)): -1}

# %%
boundary_op(v,g5).dic
# Out:
# {((0, 1),): -6, ((0, 2),): -6, ((0, 3),): -6, ((0, 4),): -6, ((1, 2),): 2, ((1
# , 3),): 2, ((1, 4),): 2, ((2, 3),): 6, ((2, 4),): 6, ((3, 4),): 6}

# %%
c1 = Group_p_chains([(1,2,3)],[-3])
boundary_op(c1,nx.complete_graph(4)).dic
# Out:
# {(1, 2): -3, (1, 3): 3, (2, 3): -3}

# %%
dc1=boundary_op(c1,nx.complete_graph(4))
ddc1=boundary_op(dc1,nx.complete_graph(4))
ddc1.dic
# Out:
# {(1,): 0, (2,): 0, (3,): 0}

# %%
boundary_op(c1+c4,nx.complete_graph(5)).dic
# Out:
# {(1, 2): 4, (1, 3): -4, (2, 3): 0, (2, 4): 4, (3, 4): -4}
